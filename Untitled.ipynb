# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ratings = pd.read_csv("data/Ratings.csv")
users = pd.read_csv("data/Users.csv")
books = pd.read_csv("data/Books.csv",low_memory=False)

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.shape
# Out:
# (271360, 8)

# %%
users.shape
# Out:
# (278858, 3)

# %%
df = pd.merge(ratings, users, on='User-ID')

# %%
df = pd.merge(df, books, on='ISBN')

# %%
df.head()
# Out:
#    User-ID        ISBN  Book-Rating                       Location   Age  \
# 0   276725  034545104X            0              tyler, texas, usa   NaN
# 1   276726  0155061224            5       seattle, washington, usa   NaN
# 2   276727  0446520802            0  h, new south wales, australia  16.0
# 3   276729  052165615X            3           rijeka, n/a, croatia  16.0
# 4   276729  0521795028            6           rijeka, n/a, croatia  16.0
#
#                                           Book-Title      Book-Author  \
# 0                               Flesh Tones: A Novel       M. J. Rose
# 1                                   Rites of Passage       Judith Rae
# 2                                       The Notebook  Nicholas Sparks
# 3                                     Help!: Level 1    Philip Prowse
# 4  The Amsterdam Connection : Level 4 (Cambridge ...      Sue Leather
#
#   Year-Of-Publication                   Publisher  \
# 0                2002            Ballantine Books
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1031136 entries, 0 to 1031135
# Data columns (total 12 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   User-ID              1031136 non-null  int64
#  1   ISBN                 1031136 non-null  object
#  2   Book-Rating          1031136 non-null  int64
#  3   Location             1031136 non-null  object
#  4   Age                  753301 non-null   float64
#  5   Book-Title           1031136 non-null  object
#  6   Book-Author          1031134 non-null  object
#  7   Year-Of-Publication  1031136 non-null  object
#  8   Publisher            1031134 non-null  object
#  9   Image-URL-S          1031136 non-null  object
#  10  Image-URL-M          1031136 non-null  object
#  11  Image-URL-L          1031132 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 94.4+ MB

# %%
df.drop(columns = ['Location','Age','Image-URL-S','Image-URL-M','Image-URL-L'],inplace=True)

# %%
df.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6
#
#                                           Book-Title      Book-Author  \
# 0                               Flesh Tones: A Novel       M. J. Rose
# 1                                   Rites of Passage       Judith Rae
# 2                                       The Notebook  Nicholas Sparks
# 3                                     Help!: Level 1    Philip Prowse
# 4  The Amsterdam Connection : Level 4 (Cambridge ...      Sue Leather
#
#   Year-Of-Publication                   Publisher
# 0                2002            Ballantine Books
# 1                2001                      Heinle
# 2                1996                Warner Books
# 3                1999  Cambridge University Press
# 4                2001  Cambridge University Press

# %%
df.isnull().sum()
# Out:
# User-ID                0
# ISBN                   0
# Book-Rating            0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.iloc[np.random.choice(len(df), 50000, replace=True)]

# %%
df.shape
# Out:
# (50000, 7)

# %%
df_grouped = df.groupby('Year-Of-Publication')['Book-Rating'].mean()  # Aggregate ratings by year
plt.figure(figsize=(12, 6))
plt.bar(df_grouped.index, df_grouped.values)
plt.xlabel("Year of Publication")
plt.ylabel("Average Book Rating")
plt.title("Average Book Rating per Year")
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.show()

# %%
user_counts = df['User-ID'].value_counts()

# %%
user_counts
# Out:
# User-ID
# 144667    728
# 205041    715
# 189139    714
# 198711    706
# 236280    705
#          ...
# 267444    618
# 33974     610
# 190925    608
# 177458    606
# 245650    589
# Name: count, Length: 75, dtype: int64

# %%
active_users = user_counts[user_counts >= 5].index

# %%
active_users
# Out:
# Index([144667, 205041, 189139, 198711, 236280,  96320, 217121, 209756, 238120,
#        233451,  88677,  98391, 113270, 127914, 252628, 224099,  44824, 117539,
#        173415,  68029, 238347,  82794, 106127, 137589,  26593,  25178,  20336,
#        150894, 131154,  56804,  58911, 229313, 177073,  60941, 202620,  64316,
#        122801, 142801,  52853,  93565, 234281, 182085, 164096, 239014,  37950,
#        193560, 129716,  52350, 153361,   4017, 234565,  55492,  93372,  82831,
#        237264, 148305, 135265, 214272,  20172, 199772,  98741, 181687, 142017,
#         36836,  28360, 257615, 184299, 151589, 233917,   9417, 267444,  33974,
#        190925, 177458, 245650],
#       dtype='int64', name='User-ID')

# %%
df = df[df['User-ID'].isin(active_users)]

# %%
df.shape
# Out:
# (50000, 7)

# %%
sns.pairplot(df)

# %%
sns.relplot(x='Book-Rating', y = 'Book-Author', data=df)

# %%
sns.distplot(df['Book-Rating'])
# Out:
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_14368\1970686997.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Book-Rating'])
# <Axes: xlabel='Book-Rating', ylabel='Density'>

# %%
plotScatterMatrix(df, 12, 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 plotScatterMatrix(df, 12, 10)
#
# NameError: name 'plotScatterMatrix' is not defined

# %%
df['Book-Rating'].mean()
# Out:
# np.float64(3.77928)

# %%
books['Book-Rating'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Book-Rating'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 books['Book-Rating'].mean()
#
# ...

# %%
import matplotlib.pyplot as plt

# Assuming dist_book and dist_user are your data arrays or lists

# Plotting the distribution for books
plt.figure(figsize=(10, 6))
plt.hist(books, bins=30, color='skyblue', edgecolor='black')
plt.title('Book Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Plotting the distribution for users
plt.figure(figsize=(10, 6))
plt.hist(users, bins=30, color='lightgreen', edgecolor='black')
plt.title('User Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1822, in Axis.convert_units(self, x)
#    1821 try:
# -> 1822     ret = self._converter.convert(x, self.units, self)
#    1823 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:57, in StrCategoryConverter.convert(value, unit, axis)
#      56 # force an update so it also does type checking
# ---> 57 unit.update(values)
#      58 s = np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:217, in UnitData.update(self, data)
#     215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
# ...
